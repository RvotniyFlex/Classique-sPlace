# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def gbm_path_generator(n_paths, n_steps, T, r, sigma, S_0):

    # Create 
    Z = np.random.normal(0.0, 1.0, [n_paths, n_steps])
    X = np.zeros([n_paths, n_steps + 1])
    time = np.zeros(n_steps + 1)
    
    X[:, 0] = np.log(S_0)
    dt = T / float(n_steps)

    for k in range(0, n_steps):
        X[:, k+1] = X[:, k] + (r - 0.5 * sigma**2) * dt + sigma * np.sqrt(dt) * Z[:, k]
        time[k+1] = time[k] + dt
    
    S = np.exp(X)
    paths = {'S': S, 'time': time}

    return paths

# %%
def main_calculation():
    n_paths = 25
    n_steps = 500
    T = 1
    r = 0.1
    sigma = 0.4
    S_0 = 100

    paths = gbm_path_generator(n_paths, n_steps, T, r, sigma, S_0)
    GBM = paths['S']
    time_grid = paths['time']

    plt.figure(figsize = (10, 6))
    plt.plot(time_grid, np.transpose(GBM))
    plt.grid()
    plt.xlabel('t')
    plt.ylabel('X(t)')

# %%
main_calculation()
