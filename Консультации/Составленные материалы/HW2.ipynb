# %% [markdown]
# # Домашняя работа 2. Парсинг

# %% [markdown]
# ## Содержание:
# * [Задача 1. (4 балла)](#Задача-1.-(4-балла))
# * [Задача 2. Спарси мне поесть](#Задача-2.-Спарси-мне-поесть)
#     * [Задача 2 а) (2 балла)](#a.-(2-балла))
#     * [Задача 2 b) (1 балл)](#b.-(1-балл))
#     * [Задача 2 c) (3 балла)](#c.-(3-балла))

# %% [markdown]
# ### Задача 1. (4 балла)

# %% [markdown]
# На сайте Минюста вывешен список иноагентов (https://minjust.gov.ru/ru/documents/7755/).
# Вам нужно получить данные из таблицы с иноагентами и создать словарь, где ключ – иноагент из списка, а значение – дата его добавления в этот список. Затем вам нужно проверить, является ли вводимое СМИ с клавиатуры иноагентом. Если оно действительно им является, нужно вывести дату, когда его объявили ИО. В противном случае нужно вывести 'NO'.

# %% [markdown]
# ##### Пример ввода/вывода данных:

# %% [markdown]
# | **Ввод**                                                                              | **Вывод** |
# | ------------------------------------------------------------------------------------- | --------- |
# | Татаро-башкирская служба Радио Свобода (Azatliq Radiosi)                              | 05.12.2017|
# | РБК Новости | NO |

# %% [markdown]
# #### Решение:

# %% [markdown]
# ### Задача 2. Спарси мне поесть

# %% [markdown]
# ![pelmeni.jpg](attachment:pelmeni.jpg)

# %% [markdown]
# #### a. (2 балла)

# %% [markdown]
# Ваш друг попросил скинуть ему подборку рецептов пельменей. Он хочет найти идеальный рецепт, которым будет пользоваться до конца жизни. Вы решили помочь ему и при этом воспользоваться великим и могучим Питоном, чтобы не заниматься однотипным копипастом вечность.
#
# ##### Ваша задача:
#
# 1. C сайта (https://www.russianfood.com/recipes/bytype/?fid=64#rcp_list) получить ссылку на  каждый рецепт с первой страницы сайта и загрузить её словарь, у которого ключом будет название рецепта, а значением - ссылка на рецепт.
# 2. Затем этот словарь нужно отсортировать по алфавиту по значению ключа и вывести в формате:
#
# **ключ(название): значение(ссылка)**
#
# **Обратите внимание, что названия рецептов на сайте могут повторяться, а соответственно ключи с одинаковыми названиями постоянно будут заменяться на новые, и старые значения будут удаляться.** Нужно придумать способ, который позволит добавить в словарь повторяющиеся названия без потери старых значений.

# %% [markdown]
# ##### Пример вывода:
#
# Баоцзы по шаньдунски: https://www.russianfood.com/recipes/recipe.php?rid=117014
#
# Вегетарианские пельмени с цветной капустой: https://www.russianfood.com/recipes/recipe.php?rid=151667
#
# Домашние пельмени: https://www.russianfood.com/recipes/recipe.php?rid=152967
#
# Жареные пельмени готи с мясным фаршем и капустой: https://www.russianfood.com/recipes/recipe.php?rid=162773
#
# Заварное тесто для вареников и пельменей: https://www.russianfood.com/recipes/recipe.php?rid=139407
#
# Запечённые открытые манты с соусом из кефира и сметаны: https://www.russianfood.com/recipes/recipe.php?rid=153773
#
# ... и т.д. до буквы "я"

# %% [markdown]
# ##### Решение:

# %% [markdown]
# #### b. (1 балл)

# %% [markdown]
# Другу не хватило рецептов и ему нужно еще больше пельменей.
#
# Получите данные с первых четырех страниц сайта и сохраните их в аналогичном формате, как в предыдущем пункте, в словарь, отсортированный по алфавиту. **Учтите, что это должно работать в общем виде для N страниц, где N - любое целое положительное число**

# %% [markdown]
# ##### Решение:

# %% [markdown]
# #### c. (3 балла)

# %% [markdown]
# В зависимости от вашей позиции в списке группы, вам надо будет перейти внутрь ссылкок рецептов и получить:
# 1. Название
# 2. Время приготовления и количество порций
# 3. Автора рецепта
# 4. Дату публикации
# 5. Описание
# 6. Ингредиенты и граммовки
#
# Начиная с N-того рецепта, где N – ваш порядковый номер в списке группы, в отсортированном списке с ссылками вы должны перейти по 10 различным ссылкам по порядку, собрать эти данные и загрузить в такой словарь:

# %%
    recipe_info ={
                'Название рецепта': '', 
                'Время приготовления и количество порций': '',
                'Автор рецепта': '',
                'Дата публикации': '',
                'Описание': '',
                'Продукты для рецепта': ''
                }

# %% [markdown]
# Если каких-то данных у рецепта не будет (а такое точно возможно), то необходимо оставить пропуск в значении соответствующего ключа. Затем все словари с каждой страницы рецепта нужно объединить в один список.

# %% [markdown]
# ##### Решение:
