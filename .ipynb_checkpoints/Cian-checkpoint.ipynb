# %%
import pandas as pd

# %%
df = pd.read_csv(r'DFs/cian_2021.csv', index_col=0 )

# %%
df
# Out:
#        city district                         region         metro  \
# 0    Москва     ЮЗАО                   р-н Коньково      Коньково
# 1    Москва     СВАО                   р-н Отрадное     Владыкино
# 2    Москва     ЮВАО                  р-н Лефортово  Авиамоторная
# 3    Москва      ЮАО                р-н Даниловский    Павелецкая
# 4    Москва     ЮЗАО                р-н Теплый Стан   Теплый Стан
# ..      ...      ...                            ...           ...
# 615  Москва      ЦАО              р-н Замоскворечье    Павелецкая
# 616  Москва     ЮЗАО               р-н Южное Бутово        Бутово
# 617  Москва      ЮАО                   р-н Царицыно      Царицыно
# 618  Москва     СВАО                   р-н Отрадное      Дегунино
# 619  Москва      ЮАО  р-н Орехово-Борисово Северное       Орехово
#
#                             adress  age_of_construction  rooms_in_flat  \
# 0          улица Островитянова 35А               1978.0            2.0
# 1             Алтуфьевское шоссе 2               1990.0            2.0
# 2            Авиамоторная улица 35               1969.0            3.0
# 3        Павелецкая набережная 2С2               1999.0            6.0
# 4            улица Теплый Стан 5К3               1975.0            2.0
# ..                             ...                  ...            ...
# 615  1-й Новокузнецкий переулок 13               1952.0            3.0
# 616          Старонародная улица 4               1995.0            2.0
# 617          Каспийская улица 28К2               1965.0            2.0
# 618          Алтуфьевское шоссе 24               1969.0            3.0
# 619        Шипиловский проезд 43К4               1975.0            3.0
#
#      rooms_to_rent apartment_layout  ceiling_height  ... height to_metro  \
# 0              1.0    Изолированная             NaN  ...   17.0        7
# 1              1.0    Изолированная            2.70  ...   16.0        3
# 2              1.0              NaN             NaN  ...    5.0        5
# 3              1.0    Изолированная            3.00  ...    4.0       15
# 4              1.0    Изолированная            2.48  ...   16.0        5
# ..             ...              ...             ...  ...    ...      ...
# 615            1.0    Изолированная            3.00  ...    5.0        7
# 616            1.0    Изолированная            2.64  ...   14.0        4
# 617            1.0    Изолированная            2.48  ...    5.0        5
# 618            1.0              NaN             NaN  ...    9.0       11
# 619            1.0    Изолированная            2.48  ...   16.0        6
#
#     type_of_way  price  kitchen_size  room_size  building_age share_in_flat  \
# 0        пешком  21000     12.000000  14.000000          43.0      0.500000
# 1        пешком  30000      8.638803  20.000000          31.0      0.500000
# 2        пешком  30000      8.000000  15.000000          52.0      0.333333
# 3        пешком  20000     15.000000  10.000000          22.0      0.166667
# 4        пешком  18000      7.000000  15.000000          46.0      0.500000
# ..          ...    ...           ...        ...           ...           ...
# 615      пешком  17000      9.000000  19.000000          69.0      0.333333
# 616      пешком  17000     10.000000  16.000000          26.0      0.500000
# 617      пешком  17000      6.000000  19.000000          56.0      0.500000
# 618      пешком  17000      8.638803  15.559046          52.0      0.333333
# 619      пешком  17000     10.000000  24.000000          46.0      0.333333
#
#      remont_scale  price_per_square
# 0               1       1500.000000
# 1               2       1500.000000
# 2               2       2000.000000
# 3               1       2000.000000
# 4               1       1200.000000
# ..            ...               ...
# 615             0        894.736842
# 616             2       1062.500000
# 617             1        894.736842
# 618             1       1092.611973
# 619             1        708.333333
#
# [620 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# city                     0
# district                 0
# region                   0
# metro                    0
# adress                   0
# age_of_construction      0
# rooms_in_flat            0
# rooms_to_rent            0
# apartment_layout       166
# ceiling_height         312
# restroom               148
# bathroom               154
# remont                   0
# window_view            272
# floor_of_flat            0
# height                   0
# to_metro                 0
# type_of_way              0
# price                    0
# kitchen_size             0
# room_size                0
# building_age             0
# share_in_flat            0
# remont_scale             0
# price_per_square         0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop(['region', 'metro', 'adress', 'type_of_way', 'restroom', 'price_per_square'], axis=1)

# %%
df
# Out:
#        city district  age_of_construction  rooms_in_flat  rooms_to_rent  \
# 1    Москва     СВАО               1990.0            2.0            1.0
# 3    Москва      ЮАО               1999.0            6.0            1.0
# 4    Москва     ЮЗАО               1975.0            2.0            1.0
# 9    Москва      ЮАО               1976.0            2.0            1.0
# 10   Москва     СВАО               1973.0            3.0            1.0
# ..      ...      ...                  ...            ...            ...
# 610  Москва     СВАО               1971.0            3.0            1.0
# 614  Москва      САО               1988.0            2.0            1.0
# 616  Москва     ЮЗАО               1995.0            2.0            1.0
# 617  Москва      ЮАО               1965.0            2.0            1.0
# 619  Москва      ЮАО               1975.0            3.0            1.0
#
#     apartment_layout  ceiling_height bathroom         remont  window_view  \
# 1      Изолированная            2.70     Есть     Евроремонт          1.0
# 3      Изолированная            3.00     Есть  Косметический          2.0
# 4      Изолированная            2.48     Есть  Косметический          2.0
# 9      Изолированная            2.64     Есть  Косметический          1.0
# 10     Изолированная            2.70     Есть     Евроремонт          2.0
# ..               ...             ...      ...            ...          ...
# 610    Изолированная            2.64     Есть  Косметический          2.0
# 614    Изолированная            2.64     Есть     Евроремонт          2.0
# 616    Изолированная            2.64     Есть     Евроремонт          2.0
# 617    Изолированная            2.48     Есть  Косметический          2.0
# 619    Изолированная            2.48     Есть  Косметический          2.0
#
#      floor_of_flat  height  to_metro  price  kitchen_size  room_size  \
# 1              7.0    16.0         3  30000      8.638803       20.0
# 3              1.0     4.0        15  20000     15.000000       10.0
# 4              2.0    16.0         5  18000      7.000000       15.0
# 9              5.0     9.0        10  13000      8.000000       15.0
# 10            11.0    14.0         2  20000     10.000000       17.0
# ..             ...     ...       ...    ...           ...        ...
# 610           10.0    14.0         7  17000      8.000000       15.0
# 614            7.0    14.0        11  17000     10.000000       20.0
# 616            5.0    14.0         4  17000     10.000000       16.0
# 617            5.0     5.0         5  17000      6.000000       19.0
# 619            5.0    16.0         6  17000     10.000000       24.0
#
#      building_age  share_in_flat  remont_scale
# 1            31.0       0.500000             2
# 3            22.0       0.166667             1
# 4            46.0       0.500000             1
# 9            45.0       0.500000             1
# 10           48.0       0.333333             2
# ..            ...            ...           ...
# 610          50.0       0.333333             1
# 614          33.0       0.500000             2
# 616          26.0       0.500000             2
# 617          56.0       0.500000             1
# 619          46.0       0.333333             1
#
# [179 rows x 19 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(1, 1, figsize = (15,9))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', ax=ax);

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['price']
X = df.drop(['price'], axis=1)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
np.random.seed(2)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error

# %%
print ("Train: {}".format(mean_squared_error(y_train, lr.predict(X_train))))
print ("Test: {}".format(mean_squared_error(y_test, lr.predict(X_test))))
# Out:
# Train: 4004690.8560256627
# Test: 4432425.713981659

# %%
for col, coef in zip(X.columns, lr.coef_):
    print('{}: {:.2f}'.format(col, coef))
# Out:
# age_of_construction: -111.45
# rooms_in_flat: -418.43
# rooms_to_rent: -0.00
# ceiling_height: 623.72
# window_view: -69.86
# floor_of_flat: 46.70
# height: -26.42
# to_metro: -290.46
# kitchen_size: 588.28
# room_size: 719.21
# building_age: 111.45
# share_in_flat: 234.08
# remont_scale: 627.10
# district_ЗАО: 366.62
# district_ЗелАО: 36.58
# district_НАО (Новомосковский): -0.00
# district_САО: 108.22
# district_СВАО: 856.87
# district_СЗАО: 147.10
# district_ЦАО: 391.57
# district_ЮАО: 757.67
# district_ЮВАО: 249.19
# district_ЮЗАО: 113.26
# apartment_layout_Смежная: -61.20
# remont_Евроремонт: 307.79
# remont_Косметический: 32.87

# %%
w = np.sum(lr.coef_)

# %%
for col, coef in zip(X.columns, lr.coef_):
    print('{}: {:.2f}%'.format(col, coef/w*100))
# Out:
# age_of_construction: -2.09%
# rooms_in_flat: -7.84%
# rooms_to_rent: -0.00%
# ceiling_height: 11.68%
# window_view: -1.31%
# floor_of_flat: 0.87%
# height: -0.49%
# to_metro: -5.44%
# kitchen_size: 11.02%
# room_size: 13.47%
# building_age: 2.09%
# share_in_flat: 4.38%
# remont_scale: 11.74%
# district_ЗАО: 6.86%
# district_ЗелАО: 0.68%
# district_НАО (Новомосковский): -0.00%
# district_САО: 2.03%
# district_СВАО: 16.04%
# district_СЗАО: 2.75%
# district_ЦАО: 7.33%
# district_ЮАО: 14.19%
# district_ЮВАО: 4.67%
# district_ЮЗАО: 2.12%
# apartment_layout_Смежная: -1.15%
# remont_Евроремонт: 5.76%
# remont_Косметический: 0.62%
